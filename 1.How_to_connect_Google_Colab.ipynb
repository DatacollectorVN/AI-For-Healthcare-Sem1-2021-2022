# %% [markdown]
# ### 1. Connect Colab to Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### 2. Change directory your workspace (Optional)
#
# ![image.png](data:image/png;base64,...)

# %%
# %cd "/content/gdrive/MyDrive/BME/TA/AI4Healthcare-sem1-2021-2022/TA-sessions/Ses-3"
# Out:
# /content/gdrive/MyDrive/BME/TA/AI4Healthcare-sem1-2021-2022/TA-sessions/Ses-3

# %% [markdown]
# ### 3. Using GPU (Requirement)
# Runtime --> Change runtime type --> Harware accelerator: GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Verification
#
# This code below will display all files and folder in the directory that you change before.

# %%
# !ls
# Out:
# 1.How-to-connect-Google-Colab

# %% [markdown]
# ### 4. Shut down workspace
#
# If you use multiple workspace with GPU, you must shutdown the other cause Google Colab just support only 1 workspace with GPU
#
# Click the Ram/Disk icon in the taskbar --> Manage sessions --> TERMINATE
#
# ![image.png](data:image/png;base64,...)
